# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 10]

# %%
# calculate differences between browser and os data
def get_differences(browser: pd.Series, os: pd.Series) -> list:
    assert len(browser) == len(os)
    diffs = [] 
    for i in range(0, len(browser)):
        diffs.append(abs(browser.loc[i] - os.loc[i]))

    return diffs

# %%
# firefox stresstest | idle
firefox = pd.read_csv("./firefox_stresstest/complete.csv")
firefox_diffs_natural_idle = get_differences(firefox['browser_natural_idle'], firefox['os_natural_idle'])
firefox_diffs_machine_idle = get_differences(firefox['browser_machine_idle'], firefox['os_machine_idle'])

plt.title('Timing differences between input events in Browser and native application (Firefox)', fontsize=18)
plt.ylabel('Differences in seconds', fontsize=18)
plt.xlabel('Event', fontsize=18)
plt.plot(firefox_diffs_natural_idle, label= "Keyboard Input")
plt.plot(firefox_diffs_machine_idle, label= "Script Input")
plt.legend()
plt.show()

# plot firefox
plt.boxplot([firefox_diffs_natural_idle, firefox_diffs_machine_idle], labels=["Differences with manual input",
            "Differences with machine input"], showfliers=False, showmeans=True)
plt.title("Timing differences between input events in Browser and native application (Firefox | Stresstest idle)", fontsize=18)
plt.xticks(fontsize=18)
plt.xlabel("", fontsize=18)
plt.ylabel("Differences in seconds", fontsize=18)
plt.tight_layout()
plt.savefig("./firefox_stresstest/fig_idle.jpeg", bbox_inches="tight", pad_inches=0.3)
plt.show()

# %%
# firefox stresstest | busy abovenormal
firefox = pd.read_csv("./firefox_stresstest/complete.csv")
firefox_diffs_natural_busy_abovenormal = get_differences(firefox['browser_natural_busy_abovenormal'], firefox['os_natural_busy_abovenormal'])
firefox_diffs_machine_busy_abovenormal = get_differences(firefox['browser_machine_busy_abovenormal'], firefox['os_machine_busy_abovenormal'])

plt.title('Timing differences between input events in Browser and native application (Firefox)', fontsize=18)
plt.ylabel('Differences in seconds', fontsize=18)
plt.xlabel('Event', fontsize=18)
plt.plot(firefox_diffs_natural_busy_abovenormal, label= "Keyboard Input")
plt.plot(firefox_diffs_machine_busy_abovenormal, label= "Script Input")
plt.legend()
plt.show()

# plot firefox
plt.boxplot([firefox_diffs_natural_busy_abovenormal, firefox_diffs_machine_busy_abovenormal], labels=["Differences with manual input",
            "Differences with machine input"], showfliers=False, showmeans=True)
plt.title("Timing differences between input events in Browser and native application (Firefox | Stresstest busy abovenormal)", fontsize=18)
plt.xticks(fontsize=18)
plt.xlabel("", fontsize=18)
plt.ylabel("Differences in seconds", fontsize=18)
plt.tight_layout()
plt.savefig("./firefox_stresstest/fig_busy_abovenormal.jpeg", bbox_inches="tight", pad_inches=0.3)
plt.show()

# %%
# firefox stresstest | maximum normal
firefox = pd.read_csv("./firefox_stresstest/complete.csv")
firefox_diffs_natural_maximum_normal = get_differences(firefox['browser_natural_maximum_normal'], firefox['os_natural_maximum_normal'])
firefox_diffs_machine_maximum_normal = get_differences(firefox['browser_machine_maximum_normal'], firefox['os_machine_maximum_normal'])

plt.title('Timing differences between input events in Browser and native application (Firefox | Stresstest maximum normal)', fontsize=18)
plt.ylabel('Differences in seconds', fontsize=18)
plt.xlabel('Event', fontsize=18)
plt.plot(firefox_diffs_natural_maximum_normal, label= "Keyboard Input")
plt.plot(firefox_diffs_machine_maximum_normal, label= "Script Input")
plt.legend()
plt.show()

# plot firefox
plt.boxplot([firefox_diffs_natural_maximum_normal, firefox_diffs_machine_maximum_normal], labels=["Differences with manual input",
            "Differences with machine input"], showfliers=False, showmeans=True)
plt.title("Timing differences between input events in Browser and native application (Firefox)", fontsize=18)
plt.xticks(fontsize=18)
plt.xlabel("", fontsize=18)
plt.ylabel("Differences in seconds", fontsize=18)
plt.tight_layout()
plt.savefig("./firefox_stresstest/fig_maximum_normal.jpeg", bbox_inches="tight", pad_inches=0.3)
plt.show()

# %%
# firefox stresstest | medium abovenormal
firefox = pd.read_csv("./firefox_stresstest/complete.csv")
firefox_diffs_natural_medium_abovenormal = get_differences(firefox['browser_natural_medium_abovenormal'], firefox['os_natural_medium_abovenormal'])
firefox_diffs_machine_medium_abovenormal = get_differences(firefox['browser_machine_medium_abovenormal'], firefox['os_machine_medium_abovenormal'])

plt.title('Timing differences between input events in Browser and native application (Firefox | Stresstest maximum normal)', fontsize=18)
plt.ylabel('Differences in seconds', fontsize=18)
plt.xlabel('Event', fontsize=18)
plt.plot(firefox_diffs_natural_medium_abovenormal, label= "Keyboard Input")
plt.plot(firefox_diffs_machine_medium_abovenormal, label= "Script Input")
plt.legend()
plt.show()

# plot firefox
plt.boxplot([firefox_diffs_natural_medium_abovenormal, firefox_diffs_machine_medium_abovenormal], labels=["Differences with manual input",
            "Differences with machine input"], showfliers=False, showmeans=True)
plt.title("Timing differences between input events in Browser and native application (Firefox | Stresstest medium abovenormal)", fontsize=18)
plt.xticks(fontsize=18)
plt.xlabel("", fontsize=18)
plt.ylabel("Differences in seconds", fontsize=18)
plt.tight_layout()
plt.savefig("./firefox_stresstest/fig_medium_abovenormal.jpeg", bbox_inches="tight", pad_inches=0.3)
plt.show()

# %%
# plot
plt.boxplot([
    firefox_diffs_natural_idle, firefox_diffs_machine_idle,
    firefox_diffs_natural_busy_abovenormal, firefox_diffs_machine_busy_abovenormal,
    firefox_diffs_natural_maximum_normal, firefox_diffs_machine_maximum_normal,
    firefox_diffs_natural_medium_abovenormal, firefox_diffs_machine_medium_abovenormal,
    ], labels=[
    "Keyboard input (idle)", "Script input (idle)",
    "Keyboard input (busy abovenormal)", "Script input (busy abovenormal)",
    "Keyboard input (maximum normal)", "Script input (maximum normal)",
    "Keyboard input (medium abovenormal)", "Script input (medium abovenormal)",
    ], showfliers=False, showmeans=True)
plt.title("Timing differences between input events in Browser and native application ( Firefox | Stresstest)", fontsize=22)
plt.xticks(fontsize=18, rotation= 30)
plt.xlabel("", fontsize=18)
plt.ylabel("Differences in seconds", fontsize=18)
plt.tight_layout()
plt.savefig("./fig_stresstest.jpeg", bbox_inches="tight", pad_inches=0.3)
plt.show()
